# %%
import tensorflow as tf

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.array([-7,-4,-1,2,5,8,11,14])
y = np.array([3,6,9,12,15,18,21,24])
plt.scatter(x,y)

# %%
input_shape = x.shape
output_shape = y.shape

# %%
# turn our numpy arrays into tensors
x = tf.constant(x)
y = tf.constant(y)
(tf.expand_dims(x, axis=-1))
# Out:
# <tf.Tensor: shape=(8, 1), dtype=int64, numpy=
# array([[-7],
#        [-4],
#        [-1],
#        [ 2],
#        [ 5],
#        [ 8],
#        [11],
#        [14]])>

# %%
# create a model - define input and output
# compiling a model
# fitting a model

tf.random.set_seed(42)
model = tf.keras.Sequential()
model.add(tf.keras.layers.Dense(1))
model.compile(loss = tf.keras.losses.mae,
            optimizer = tf.keras.optimizers.SGD(),
             metrics = ["mae"])
#model.fit(x,y,epochs = 5)
model.fit(tf.expand_dims(x, axis=-1), y, epochs=5)
# Out:
# Epoch 1/5
# 1/1 [==============================] - 1s 745ms/step - loss: 9.1036 - mae: 9.1036
# Epoch 2/5
# 1/1 [==============================] - 0s 22ms/step - loss: 8.9711 - mae: 8.9711
# Epoch 3/5
# 1/1 [==============================] - 0s 41ms/step - loss: 8.8386 - mae: 8.8386
# Epoch 4/5
# 1/1 [==============================] - 0s 14ms/step - loss: 8.7061 - mae: 8.7061
# Epoch 5/5
# 1/1 [==============================] - 0s 24ms/step - loss: 8.5736 - mae: 8.5736

# %%
model.predict([5])
# Out:
# 1/1 [==============================] - 0s 120ms/step
# array([[7.205618]], dtype=float32)

# %% [markdown]
# Improving the model

# %%
# create a model - define input and output
# compiling a model
# fitting a model

tf.random.set_seed(42)
model = tf.keras.Sequential()
model.add(tf.keras.layers.Dense(1))
model.compile(loss = tf.keras.losses.mae,
            optimizer = tf.keras.optimizers.Adam(learning_rate = 0.0001),
             metrics = ["mae"])
#model.fit(x,y,epochs = 5)
model.fit(tf.expand_dims(x, axis=-1), y, epochs=100)

# %%
model.predict([17])
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7b8ddf3be320> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 293ms/step
# array([[24.350573]], dtype=float32)

# %%
# create the model
model = tf.keras.Sequential([
    tf.keras.layers.Dense(50),
    tf.keras.layers.Dense(1)
])
# compile the model -- loss,optimizer,metrics
model.compile(loss = "mae",
              optimizer = tf.keras.optimizers.Adam(learning_rate=0.01),
              metrics = ["mae"])
# fit the model
#model.fit(tf.expand_dims(x,axis=-1),y,100)
model.fit(tf.expand_dims(x, axis=-1), y, epochs=100)

# %%
model.predict([17])

# %%
# design the model
# compile the model -- losses,optimizer , metrics
# fit the model

model = tf.keras.Sequential([
    tf.keras.layers.Dense(1)
])
model.compile(loss= "mae",
              optimizer = tf.keras.optimizers.SGD(),
              metrics = ["mae"])
model.fit(tf.expand_dims(x,axis=-1),y,10)
# Out:
# WARNING:tensorflow:6 out of the last 105 calls to <function Model.make_train_function.<locals>.train_function at 0x7b8ddef03e20> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 1s 670ms/step - loss: 8.6181 - mae: 8.6181
